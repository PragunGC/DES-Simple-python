# %%
#Key Generation
key_string=input("Enter key value")
key_int=int(key_string,16)
key_bin=bin(key_int)
key_bin=key_bin[2:len(key_bin)]
if len(key_string)*4!=len(key_bin):
    n_0s=len(key_string)*4-len(key_bin)
    for i in range(n_0s):
        key_bin="0"+key_bin
print(key_bin)
PC1=[56, 48, 40, 32, 24, 16, 8,
	0, 57, 49, 41, 33, 25, 17,
	9,  1, 58, 50, 42, 34, 26,
	18, 10,  2, 59, 51, 43, 35,
	62, 54, 46, 38, 30, 22, 14,
	6, 61, 53, 45, 37, 29, 21,
	13,  5, 60, 52, 44, 36, 28,
	20, 12,  4, 27, 19, 11,3]

rot_table=[1, 1, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 1]
PC2=[13, 16, 10, 23,  0,  4,
	2, 27, 14,  5, 20,  9,
	22, 18, 11,  3, 25,  7,
	15,  6, 26, 19, 12,  1,
	40, 51, 30, 36, 46, 54,
	29, 39, 50, 44, 32, 47,
	43, 48, 38, 55, 33, 52,
	45, 41, 49, 35, 28, 31]
key_56=""
for i in range(len(PC1)):
    key_56+=key_bin[PC1[i]]
C=key_56[0:(len(key_56)//2)]
D=key_56[(len(key_56)//2):len(key_56)+1]
keys=[]
for i in range(len(rot_table)):
    rot_num=rot_table[i]
    temp=""
    temp=C[0:rot_num]
    left_shift_C=C[rot_num:len(C)+1]
    left_shift_C+=temp
    temp=""
    temp=D[0:rot_num]
    left_shift_D=D[rot_num:len(C)+1]
    left_shift_D+=temp
    left_rot_key=left_shift_C+left_shift_D
    C=left_shift_C
    D=left_shift_D
    temp=""
    for j in range(len(PC2)):
        temp+=left_rot_key[PC2[j]]
    keys.append(temp)
    print("Key",i+1,":",temp)
# Out:
# Enter key value 133457799BBCDFF4
# 0001001100110100010101110111100110011011101111001101111111110100
# Key 1 : 000110110000001011101111111111000111000001110110
# Key 2 : 011110011010111011011001110110111100100111100101
# Key 3 : 010101011111110010001010010000101110111110011001
# Key 4 : 011100101010110111010110111110110011010100011101
# Key 5 : 011111001110110000000111111010110101001110101010
# Key 6 : 011000111010010100111110010101000111101100101111
# Key 7 : 111011001000010010110111111101100001100011111100
# Key 8 : 111101111000101000111010110000011011101111111011
# Key 9 : 111000001101101111101011111011011110011110001001
# Key 10 : 101100011111001101000111101110100101011001001111
# Key 11 : 001000010101111111010011110111101101001110100110
# Key 12 : 011101010111000111110101100101000110111111101001
# Key 13 : 100101111100010111010001111110101011101001010001
# Key 14 : 010111110100001110110111111100111110011100111010
# Key 15 : 101111111001000110001101001111010011111100001010
# ...

# %%
#Encryption
PT_string=input("Enter plain text")
PT_int=int(PT_string,16)
PT_bin=bin(PT_int)
print(PT_bin)
PT_bin=PT_bin[2:len(PT_bin)]

if len(PT_string)*4!=len(PT_bin):
    n_0s=len(PT_string)*4-len(PT_bin)
    for i in range(n_0s):
        PT_bin="0"+PT_bin
print(PT_bin)

IP=[57, 49, 41, 33, 25, 17, 9,  1,
		59, 51, 43, 35, 27, 19, 11, 3,
		61, 53, 45, 37, 29, 21, 13, 5,
		63, 55, 47, 39, 31, 23, 15, 7,
		56, 48, 40, 32, 24, 16, 8,  0,
		58, 50, 42, 34, 26, 18, 10, 2,
		60, 52, 44, 36, 28, 20, 12, 4,
		62, 54, 46, 38, 30, 22, 14, 6
	]

PT_64=""
for i in range(len(IP)):
    PT_64+=PT_bin[IP[i]]

ET = [
		31,  0,  1,  2,  3,  4,
		 3,  4,  5,  6,  7,  8,
		 7,  8,  9, 10, 11, 12,
		11, 12, 13, 14, 15, 16,
		15, 16, 17, 18, 19, 20,
		19, 20, 21, 22, 23, 24,
		23, 24, 25, 26, 27, 28,
		27, 28, 29, 30, 31,  0
	]
sbox = [
		# S1
		[14, 4, 13, 1, 2, 15, 11, 8, 3, 10, 6, 12, 5, 9, 0, 7,
		 0, 15, 7, 4, 14, 2, 13, 1, 10, 6, 12, 11, 9, 5, 3, 8,
		 4, 1, 14, 8, 13, 6, 2, 11, 15, 12, 9, 7, 3, 10, 5, 0,
		 15, 12, 8, 2, 4, 9, 1, 7, 5, 11, 3, 14, 10, 0, 6, 13],

		# S2
		[15, 1, 8, 14, 6, 11, 3, 4, 9, 7, 2, 13, 12, 0, 5, 10,
		 3, 13, 4, 7, 15, 2, 8, 14, 12, 0, 1, 10, 6, 9, 11, 5,
		 0, 14, 7, 11, 10, 4, 13, 1, 5, 8, 12, 6, 9, 3, 2, 15,
		 13, 8, 10, 1, 3, 15, 4, 2, 11, 6, 7, 12, 0, 5, 14, 9],

		# S3
		[10, 0, 9, 14, 6, 3, 15, 5, 1, 13, 12, 7, 11, 4, 2, 8,
		 13, 7, 0, 9, 3, 4, 6, 10, 2, 8, 5, 14, 12, 11, 15, 1,
		 13, 6, 4, 9, 8, 15, 3, 0, 11, 1, 2, 12, 5, 10, 14, 7,
		 1, 10, 13, 0, 6, 9, 8, 7, 4, 15, 14, 3, 11, 5, 2, 12],

		# S4
		[7, 13, 14, 3, 0, 6, 9, 10, 1, 2, 8, 5, 11, 12, 4, 15,
		 13, 8, 11, 5, 6, 15, 0, 3, 4, 7, 2, 12, 1, 10, 14, 9,
		 10, 6, 9, 0, 12, 11, 7, 13, 15, 1, 3, 14, 5, 2, 8, 4,
		 3, 15, 0, 6, 10, 1, 13, 8, 9, 4, 5, 11, 12, 7, 2, 14],

		# S5
		[2, 12, 4, 1, 7, 10, 11, 6, 8, 5, 3, 15, 13, 0, 14, 9,
		 14, 11, 2, 12, 4, 7, 13, 1, 5, 0, 15, 10, 3, 9, 8, 6,
		 4, 2, 1, 11, 10, 13, 7, 8, 15, 9, 12, 5, 6, 3, 0, 14,
		 11, 8, 12, 7, 1, 14, 2, 13, 6, 15, 0, 9, 10, 4, 5, 3],

		# S6
		[12, 1, 10, 15, 9, 2, 6, 8, 0, 13, 3, 4, 14, 7, 5, 11,
		 10, 15, 4, 2, 7, 12, 9, 5, 6, 1, 13, 14, 0, 11, 3, 8,
		 9, 14, 15, 5, 2, 8, 12, 3, 7, 0, 4, 10, 1, 13, 11, 6,
		 4, 3, 2, 12, 9, 5, 15, 10, 11, 14, 1, 7, 6, 0, 8, 13],

		# S7
		[4, 11, 2, 14, 15, 0, 8, 13, 3, 12, 9, 7, 5, 10, 6, 1,
		 13, 0, 11, 7, 4, 9, 1, 10, 14, 3, 5, 12, 2, 15, 8, 6,
		 1, 4, 11, 13, 12, 3, 7, 14, 10, 15, 6, 8, 0, 5, 9, 2,
		 6, 11, 13, 8, 1, 4, 10, 7, 9, 5, 0, 15, 14, 2, 3, 12],

		# S8
		[13, 2, 8, 4, 6, 15, 11, 1, 10, 9, 3, 14, 5, 0, 12, 7,
		 1, 15, 13, 8, 10, 3, 7, 4, 12, 5, 6, 11, 0, 14, 9, 2,
		 7, 11, 4, 1, 9, 12, 14, 2, 0, 6, 10, 13, 15, 3, 5, 8,
		 2, 1, 14, 7, 4, 10, 8, 13, 15, 12, 9, 0, 3, 5, 6, 11],
	]
p = [
		15, 6, 19, 20, 28, 11,
		27, 16, 0, 14, 22, 25,
		4, 17, 30, 9, 1, 7,
		23,13, 31, 26, 2, 8,
		18, 12, 29, 5, 21, 10,
		3, 24
	]
PT_L=[]
PT_R=[]

PT_L.append(PT_64[:32])
PT_R.append(PT_64[32:])

for i in range(0,16):
	R_exp=""
	for j in range(len(ET)):
		R_exp+=PT_R[i][ET[j]]
	xor_ans=""
	for k in range(len(R_exp)):
		if(R_exp[k]==keys[i][k]):
			xor_ans+="0"
		else:
			xor_ans+="1"
	s_box_op=""
	count=0
	for k in range(0,48,6):
		temp_ip=xor_ans[k:k+6]
		row_no=temp_ip[0]+temp_ip[5]
		column_no=temp_ip[1:5]
		row=int(row_no,2)
		column=int(column_no,2)
		s_ip=sbox[count][(row*16)+column]
		s_ip_bin=format(s_ip,"04b")
		s_box_op+=s_ip_bin
		count+=1
	perm_op=""    
	for k in range(len(p)):
		perm_op+=s_box_op[p[k]]
	next_r=""
	for k in range(len(perm_op)):
		if(perm_op[k]==PT_L[i][k]):
			next_r+="0"
		else:
			next_r+="1"
	PT_L.append(PT_R[i])
	PT_R.append(next_r)

FP = [
		39,  7, 47, 15, 55, 23, 63, 31,
		38,  6, 46, 14, 54, 22, 62, 30,
		37,  5, 45, 13, 53, 21, 61, 29,
		36,  4, 44, 12, 52, 20, 60, 28,
		35,  3, 43, 11, 51, 19, 59, 27,
		34,  2, 42, 10, 50, 18, 58, 26,
		33,  1, 41,  9, 49, 17, 57, 25,
		32,  0, 40,  8, 48, 16, 56, 24
	]
inv_per_ip=PT_R[16]+PT_L[16]
CT_op=""
for i in range(len(FP)):
    CT_op+=inv_per_ip[FP[i]]

CT_int=int(CT_op,2)
CT_hex=hex(CT_int)
CT_hex=CT_hex[2:len(CT_hex)]
CT_hex=CT_hex.upper()
print("Cipher Text is:")
print(CT_hex)
# Out:
# Enter plain text 0123456789ABCDEF
# 0b100100011010001010110011110001001101010111100110111101111
# 0000000100100011010001010110011110001001101010111100110111101111
# Cipher Text is:
# E9D21DA2B4AE1B5F

# %%
#Decryption
CT_string=input("Enter cipher text")
CT_int=int(CT_string,16)
CT_bin=bin(CT_int)
CT_bin=CT_bin[2:len(CT_bin)]
if len(CT_string)*4!=len(CT_bin):
    n_0s=len(CT_string)*4-len(CT_bin)
    for i in range(n_0s):
        CT_bin="0"+CT_bin
print(CT_bin)
CT_64=""
for i in range(len(IP)):
    CT_64+=CT_bin[IP[i]]
CT_L=[]
CT_R=[]

CT_L.append(CT_64[:32])
CT_R.append(CT_64[32:])

for i in range(0,16):
	r_exp=""
	for j in range(len(ET)):
		r_exp+=CT_R[i][ET[j]]
	xor_ans=""
	for k in range(len(L_exp)):
		if(r_exp[k]==keys[15-i][k]):
			xor_ans+="0"
		else:
			xor_ans+="1"
	s_box_op=""
	count=0
	for k in range(0,48,6):
		temp_ip=xor_ans[k:k+6]
		row_no=temp_ip[0]+temp_ip[5]
		column_no=temp_ip[1:5]
		row=int(row_no,2)
		column=int(column_no,2)
		s_ip=sbox[count][(row*16)+column]
		s_ip_bin=format(s_ip,"04b")
		s_box_op+=s_ip_bin
		count+=1
	perm_op=""    
	for k in range(len(p)):
		perm_op+=s_box_op[p[k]]
	next_r=""
	for k in range(len(perm_op)):
		if(perm_op[k]==CT_L[i][k]):
			next_r+="0"
		else:
			next_r+="1"
	CT_L.append(CT_R[i])
	CT_R.append(next_r)

inv_per_ip=CT_R[16]+CT_L[16]
PT_op=""
for i in range(len(FP)):
    PT_op+=inv_per_ip[FP[i]]

PT_int=int(PT_op,2)
PT_hex=hex(PT_int)
PT_hex=PT_hex[2:len(PT_hex)]
if(len(PT_hex)!=16):
    for i in range(16-len(PT_hex)):
        PT_hex="0"+PT_hex
PT_hex=PT_hex.upper()
print("Plain Text is:")
print(PT_hex)
# Out:
# Enter cipher text E9D21DA2B4AE1B5F
# 1110100111010010000111011010001010110100101011100001101101011111
# Plain Text is:
# 0123456789ABCDEF
